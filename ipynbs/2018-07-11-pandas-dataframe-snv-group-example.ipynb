# %%
import pandas as pd

# %%
df = pd.read_table('test-metadata-subtyping-results.tsv')

# %%
df
# Out:
#                                  sample      scheme scheme_version  \
# 0                            SRR1958005  heidelberg          0.5.0
# 1           fail-qc-unconfident-subtype  heidelberg          0.5.0
# 2                      SRR1002850_SMALL  heidelberg          0.5.0
# 3                      SRR1002850_SMALL  heidelberg          0.5.0
# 4                            SRR1958005  heidelberg          0.5.0
# 5           fail-qc-unconfident-subtype  heidelberg          0.5.0
# 6                            SRR6126859  heidelberg          0.5.0
# 7                            SRR6126859  heidelberg          0.5.0
# 8   fail-qc-mixed-subtype-pos-neg-tiles  heidelberg          0.5.0
# 9                      SRR5646583_SMALL  heidelberg          0.5.0
# 10               inconsistent_reads_fwd  heidelberg          0.5.0
# 11               inconsistent_reads_rvs  heidelberg          0.5.0
#
#         subtype                                    all_subtypes  \
# ...

# %%
df1 = df.ix[0:6]

# %%
df1
# Out:
#                         sample      scheme scheme_version      subtype  \
# 0                   SRR1958005  heidelberg          0.5.0            1
# 1  fail-qc-unconfident-subtype  heidelberg          0.5.0          NaN
# 2             SRR1002850_SMALL  heidelberg          0.5.0  2.2.2.2.1.4
# 3             SRR1002850_SMALL  heidelberg          0.5.0  2.2.2.2.1.4
# 4                   SRR1958005  heidelberg          0.5.0            1
# 5  fail-qc-unconfident-subtype  heidelberg          0.5.0          NaN
# 6                   SRR6126859  heidelberg          0.5.0            1
#
#                                      all_subtypes  \
# 0                                               1
# 1                                             NaN
# 2  2; 2.2; 2.2.2; 2.2.2.2; 2.2.2.2.1; 2.2.2.2.1.4
# 3  2; 2.2; 2.2.2; 2.2.2.2; 2.2.2.2.1; 2.2.2.2.1.4
# 4                                               1
# 5                                             NaN
# ...

# %%
df2 = df.ix[7:]

# %%
df2
# Out:
#                                  sample      scheme scheme_version  \
# 7                            SRR6126859  heidelberg          0.5.0
# 8   fail-qc-mixed-subtype-pos-neg-tiles  heidelberg          0.5.0
# 9                      SRR5646583_SMALL  heidelberg          0.5.0
# 10               inconsistent_reads_fwd  heidelberg          0.5.0
# 11               inconsistent_reads_rvs  heidelberg          0.5.0
#
#         subtype                                    all_subtypes  \
# 7             1                                               1
# 8           1.1                                             1.1
# 9   2.2.1.1.1.1  2; 2.2; 2.2.1; 2.2.1.1; 2.2.1.1.1; 2.2.1.1.1.1
# 10          NaN                                             NaN
# 11          NaN                                             NaN
#
#                                tiles_matching_subtype  \
# 7                                3677767-1; 2531225-1
# 8   202001-1.1; 600783-1.1; 1049933-1.1; 1193219-1...
# ...

# %%
df1['group'] = 'GROUP A'
# Out:
# /home/CSCScience.ca/pkruczkiewicz/repos/bio_hansel/.venv/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df1
# Out:
#                         sample      scheme scheme_version      subtype  \
# 0                   SRR1958005  heidelberg          0.5.0            1
# 1  fail-qc-unconfident-subtype  heidelberg          0.5.0          NaN
# 2             SRR1002850_SMALL  heidelberg          0.5.0  2.2.2.2.1.4
# 3             SRR1002850_SMALL  heidelberg          0.5.0  2.2.2.2.1.4
# 4                   SRR1958005  heidelberg          0.5.0            1
# 5  fail-qc-unconfident-subtype  heidelberg          0.5.0          NaN
# 6                   SRR6126859  heidelberg          0.5.0            1
#
#                                      all_subtypes  \
# 0                                               1
# 1                                             NaN
# 2  2; 2.2; 2.2.2; 2.2.2.2; 2.2.2.2.1; 2.2.2.2.1.4
# 3  2; 2.2; 2.2.2; 2.2.2.2; 2.2.2.2.1; 2.2.2.2.1.4
# 4                                               1
# 5                                             NaN
# ...

# %%
df2['group'] = 'B'
# Out:
# /home/CSCScience.ca/pkruczkiewicz/repos/bio_hansel/.venv/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
pd.concat([df1, df2])
# Out:
#                                  sample      scheme scheme_version  \
# 0                            SRR1958005  heidelberg          0.5.0
# 1           fail-qc-unconfident-subtype  heidelberg          0.5.0
# 2                      SRR1002850_SMALL  heidelberg          0.5.0
# 3                      SRR1002850_SMALL  heidelberg          0.5.0
# 4                            SRR1958005  heidelberg          0.5.0
# 5           fail-qc-unconfident-subtype  heidelberg          0.5.0
# 6                            SRR6126859  heidelberg          0.5.0
# 7                            SRR6126859  heidelberg          0.5.0
# 8   fail-qc-mixed-subtype-pos-neg-tiles  heidelberg          0.5.0
# 9                      SRR5646583_SMALL  heidelberg          0.5.0
# 10               inconsistent_reads_fwd  heidelberg          0.5.0
# 11               inconsistent_reads_rvs  heidelberg          0.5.0
#
#         subtype                                    all_subtypes  \
# ...
